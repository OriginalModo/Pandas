# %%
import pandas as pd
df = pd.read_csv('forecast_best3')
df.info()

df.plot()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DT      16 non-null     object
#  1   ТО_НДС  16 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 384.0+ bytes
# <Axes: >

# %%
import numpy as np
df = np.log(df)
df.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'str' object has no attribute 'log'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 import numpy as np
# ----> 2 df = np.log(df)
#       3 df.plot()
#
# File E:\All_Python_Frameworks\Pandas\venv\lib\site-packages\pandas\core\generic.py:2016, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2012 @final
#    2013 def __array_ufunc__(
#    2014     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2015 ):
# -> 2016     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# File E:\All_Python_Frameworks\Pandas\venv\lib\site-packages\pandas\core\arraylike.py:404, in array_ufunc(self, ufunc, method, *inputs, **kwargs)
# ...
