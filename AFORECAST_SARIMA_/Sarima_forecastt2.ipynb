# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %run Forecast_first2.py

# %%
df=pd.read_csv('forecast_best2', index_col=0, parse_dates=True)

# %%
df.tail()
# Out:
#                  ТО_НДС
# DT
# 2023-04-12  16728365.75
# 2023-04-13  18108535.10
# 2023-04-14  22009678.94
# 2023-04-15  24114469.42
# 2023-04-16  16630633.81

# %%
# df=validate_series(df)
plt.plot(df)
